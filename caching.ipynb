# %% [markdown]
# Python-dotenv | Environment variable

# %%
from dotenv import  load_dotenv,find_dotenv
load_dotenv(find_dotenv(),override=True)

import os
id=os.environ.get("GOOGLE_API_KEY")
print(id)
# Out:
# AIzaSyA3AA5lXAFZKfVhIHAUCVsnLWXQh1lBH64

# %% [markdown]
# LLM Uses

# %%
from langchain_google_genai  import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
output=llm.invoke("what is 1june 1986 week day?")
print(output.content)
#help(ChatGoogleGenerativeAI)

# %% [markdown]
# Messages

# %%
from langchain.schema  import SystemMessage,HumanMessage,AIMessage
messages=[
    SystemMessage(content="You are a helpful assistant."),
    HumanMessage(content="what is 1june 1986 week day?")
]

output=llm.invoke(messages)
print(output.content)

# %% [markdown]
# Caching LLm Response |
# in MemoeryCache

# %%
from langchain_google_genai  import ChatGoogleGenerativeAI
from langchain.globals import set_llm_cache
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
# %%time
from langchain.cache import InMemoryCache
set_llm_cache(InMemoryCache())
output=llm.invoke("what is 2june 1986 week day?")

# %%
# %%time
llm.invoke("what is 2june 1986 week day?")

# %% [markdown]
# SQLlite Caching

# %%
from langchain.cache import SQLiteCache
set_llm_cache(SQLiteCache(database_path="llm_cache.db"))
output=llm.invoke("what is 2june 1986 week day?")
print(output.content)
# Out:
# June 2, 1986 was a **Monday**.
# CPU times: total: 0 ns
# Wall time: 6.84 ms

# %%
# %%time
output=llm.invoke("what is 2june 1986 week day?")
# Out:
# CPU times: total: 0 ns
# Wall time: 2.59 ms
